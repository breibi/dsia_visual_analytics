# %% [markdown]
# # Part 1: Analyze File Structure

# %%
import pandas as pd
import os
import gzip
import shutil
import warnings

warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
pd.options.display.max_rows = 150

# %% [markdown]
# ## Number and Size of Files
#
# First, we read the data directory from a config file:

# %%
with open('config') as f:
    path = f.readline()

# %% [markdown]
# display files and sizes:

# %%
pd.set_option('display.max_colwidth', None)
files = pd.DataFrame()
for filename in os.listdir(path):
    full_path = os.path.join(path, filename)
    files =pd.concat([files, pd.DataFrame([[filename, round(os.path.getsize(full_path)/1024)]])], ignore_index=True)

files.columns = ['filename', 'size [KB]']
files.head()
# Out:
#                                                                          filename  \
# 0  SAS-Full-Raw-Data-Export-SCO-2015-generic-28060-2019_08_13_16_39_17.100.csv.gz
# 1   SAS-Full-Raw-Data-Export-SCO-2015-generic-28060-2019_08_13_16_39_17.10.csv.gz
# 2  SAS-Full-Raw-Data-Export-SCO-2015-generic-28060-2019_08_13_16_39_17.101.csv.gz
# 3  SAS-Full-Raw-Data-Export-SCO-2015-generic-28060-2019_08_13_16_39_17.102.csv.gz
# 4  SAS-Full-Raw-Data-Export-SCO-2015-generic-28060-2019_08_13_16_39_17.103.csv.gz
#
#    size [KB]
# 0      97671
# 1      97677
# 2      97681
# 3      97670
# 4      97678

# %%
print("Number of Files: {}".format(len(files)))
print("Total Size: {} MB".format(int(files['size [KB]'].sum()/1024)))
# Out:
# Number of Files: 237
# Total Size: 22416 MB

# %% [markdown]
# ## Analyze the structure
# - we choose a sample file (nr 230 in the list)
# - unzip it to a temporary file
# - read the first chunk of 10000 entries

# %%
tmp_file = '.\\data\\tmp.csv'
sample_filename = os.listdir(path)[230]

# unzip to tmp_file
with gzip.open(os.path.join(path,sample_filename)) as f_in:
    with open(tmp_file, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)

reader = pd.read_csv(tmp_file, sep=';', chunksize=10000)
chunk = next(reader)

# %% [markdown]
# ## column names

# %%
chunk.dtypes
# Out:
# user.Id                                                    int64
# user.Email                                                object
# user.MobileNumber                                        float64
# user.FaxNumber                                           float64
# user.Identifier                                           object
# sentToMTA.Timestamp                                       object
# sentToMTA.ExternalTransactionId                          float64
# sentToMTA.SendoutChannel                                  object
# skip.Timestamp                                            object
# skip.Category                                             object
# skip.ExternalTransactionId                               float64
# bounce.Timestamp                                          object
# bounce.Category                                           object
# feedback.Timestamp                                       float64
# feedback.Category                                        float64
# render.Timestamp                                          object
# render.GeoLocation.ISOCountryCode                         object
# render.GeoLocation.RegionCode                             object
# render.GeoLocation.City                                   object
# render.GeoLocation.Latitude                              float64
# render.GeoLocation.Longitude                             float64
# render.UserAgent.Platform                                 object
# render.UserAgent.OperatingSystemName                      object
# render.UserAgent.OperatingSystemVersion                   object
# render.UserAgent.ClientName                               object
# render.UserAgent.ClientVersion                            object
# render.UserAgent.RawString                                object
# click.Timestamp                                           object
# click.Link.Id                                            float64
# click.Link.Category.Id                                   float64
# click.Link.Category.Name                                  object
# click.Link.Url                                            object
# click.Link.SystemLinkType                                float64
# click.Link.Type                                           object
# click.GeoLocation.ISOCountryCode                          object
# click.GeoLocation.RegionCode                              object
# click.GeoLocation.City                                    object
# click.GeoLocation.Latitude                               float64
# click.GeoLocation.Longitude                              float64
# click.UserAgent.Platform                                  object
# click.UserAgent.OperatingSystem                           object
# click.UserAgent.OperatingSystemVersion                    object
# click.UserAgent.ClientName                                object
# click.UserAgent.ClientVersion                             object
# click.UserAgent.RawString                                 object
# unsubscribe.Timestamp                                     object
# forward.Timestamp                                        float64
# conversion.cp.Timestamp                                  float64
# conversion.cp.Id                                         float64
# conversion.cp.Name                                       float64
# conversion.cp.OrderId                                    float64
# conversion.cp.ItemCount                                  float64
# conversion.cp.Amount                                     float64
# conversion.cp.RequestParameters                          float64
# group.Id                                                   int64
# group.Name                                                object
# group.Email                                               object
# group.Category.Id                                          int64
# group.Category.Name                                       object
# message.Id                                                 int64
# message.Name                                              object
# message.Category.Id                                      float64
# message.Category.Name                                    float64
# message.Subject.Unresolved                                object
# message.ExternalId                                       float64
# message.Type                                              object
# message.variation.Id                                      object
# selection.Id                                             float64
# selection.Name                                            object
# record.Timestamp                                          object
# record.Type                                               object
# record.sentToMTA.Timestamp                                object
# record.ExternalTransactionId                             float64
# sendout.Type                                              object
# sendout.AddresseeRole                                     object
# sendout.RecipientType                                     object
# user.DateOfBirth                                          object
# user.FirstName                                            object
# user.ISOCountryCode                                       object
# user.ISOLanguageCode                                      object
# user.LastName                                             object
# user.Nickname                                            float64
# user.PartnerId                                           float64
# user.Source                                               object
# user.TimeZone                                            float64
# user.Title                                               float64
# user.ZipCode                                              object
# user.CustomAttribute['BeSCity']                          float64
# user.CustomAttribute['BeSHome']                          float64
# user.CustomAttribute['BeSHome2']                         float64
# user.CustomAttribute['BeSHome3']                         float64
# user.CustomAttribute['BeSStreet']                        float64
# user.CustomAttribute['BesZip']                           float64
# user.CustomAttribute['BIC']                              float64
# user.CustomAttribute['City']                              object
# user.CustomAttribute['Coupon']                            object
# user.CustomAttribute['Coupon02']                         float64
# user.CustomAttribute['IBAN']                             float64
# user.CustomAttribute['Last_Open_Any_Newsletter_Date']     object
# user.CustomAttribute['PartnerID']                         object
# user.CustomAttribute['ProductID']                        float64
# user.CustomAttribute['SalesOrganization']                float64
# user.CustomAttribute['SCSMembernumber']                  float64
# user.CustomAttribute['SCS_Boutique']                     float64
# user.CustomAttribute['SCS_Boutique_City']                float64
# user.CustomAttribute['SCS_Boutique_Name1']               float64
# user.CustomAttribute['SCS_Boutique_Name2']               float64
# user.CustomAttribute['SCS_Boutique_Street']              float64
# user.CustomAttribute['SCS_Due_Date']                     float64
# user.CustomAttribute['SCS_Entry_Date']                   float64
# user.CustomAttribute['SCS_Expiry_Dat']                    object
# user.CustomAttribute['SCS_Magazine_Language_ISO']        float64
# user.CustomAttribute['SSFCardNumber']                    float64
# user.CustomAttribute['Street']                            object
# user.CustomAttribute['Street2']                          float64
# user.CustomAttribute['Street3']                          float64
# user.CustomAttribute['Telephone']                        float64
# user.CustomAttribute['TitleKey']                         float64
# dtype: object

# %% [markdown]
# ## some entries...
# but first drop personal data

# %%
chunk = chunk.drop(columns=['user.Email', 'user.MobileNumber', 'user.LastName'])
chunk.head()
# Out:
#       user.Id  user.FaxNumber user.Identifier   sentToMTA.Timestamp  \
# 0  9225239026             NaN             NaN  2018-09-15T07:33:20Z
# 1  9225239026             NaN             NaN  2018-09-04T08:46:36Z
# 2  9225239026             NaN             NaN  2018-08-29T08:46:44Z
# 3  9225239026             NaN             NaN  2018-08-25T08:46:01Z
# 4  9225239026             NaN             NaN  2018-08-20T08:31:09Z
#
#    sentToMTA.ExternalTransactionId sentToMTA.SendoutChannel skip.Timestamp  \
# 0                              NaN                    EMAIL            NaN
# 1                              NaN                    EMAIL            NaN
# 2                              NaN                    EMAIL            NaN
# 3                              NaN                    EMAIL            NaN
# 4                              NaN                    EMAIL            NaN
#
#   skip.Category  skip.ExternalTransactionId bounce.Timestamp bounce.Category  \
# 0           NaN                         NaN              NaN             NaN
# 1           NaN                         NaN              NaN             NaN
# 2           NaN                         NaN              NaN             NaN
# 3           NaN                         NaN              NaN             NaN
# 4           NaN                         NaN              NaN             NaN
#
#    feedback.Timestamp  feedback.Category render.Timestamp  \
# 0                 NaN                NaN              NaN
# 1                 NaN                NaN              NaN
# 2                 NaN                NaN              NaN
# 3                 NaN                NaN              NaN
# 4                 NaN                NaN              NaN
#
#   render.GeoLocation.ISOCountryCode render.GeoLocation.RegionCode  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
#
#   render.GeoLocation.City  render.GeoLocation.Latitude  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    render.GeoLocation.Longitude render.UserAgent.Platform  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   render.UserAgent.OperatingSystemName  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   render.UserAgent.OperatingSystemVersion render.UserAgent.ClientName  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                     NaN                         NaN
#
#   render.UserAgent.ClientVersion render.UserAgent.RawString click.Timestamp  \
# 0                            NaN                        NaN             NaN
# 1                            NaN                        NaN             NaN
# 2                            NaN                        NaN             NaN
# 3                            NaN                        NaN             NaN
# 4                            NaN                        NaN             NaN
#
#    click.Link.Id  click.Link.Category.Id click.Link.Category.Name  \
# 0            NaN                     NaN                      NaN
# 1            NaN                     NaN                      NaN
# 2            NaN                     NaN                      NaN
# 3            NaN                     NaN                      NaN
# 4            NaN                     NaN                      NaN
#
#   click.Link.Url  click.Link.SystemLinkType click.Link.Type  \
# 0            NaN                        NaN             NaN
# 1            NaN                        NaN             NaN
# 2            NaN                        NaN             NaN
# 3            NaN                        NaN             NaN
# 4            NaN                        NaN             NaN
#
#   click.GeoLocation.ISOCountryCode click.GeoLocation.RegionCode  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#   click.GeoLocation.City  click.GeoLocation.Latitude  \
# 0                    NaN                         NaN
# 1                    NaN                         NaN
# 2                    NaN                         NaN
# 3                    NaN                         NaN
# 4                    NaN                         NaN
#
#    click.GeoLocation.Longitude click.UserAgent.Platform  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
#
#   click.UserAgent.OperatingSystem click.UserAgent.OperatingSystemVersion  \
# 0                             NaN                                    NaN
# 1                             NaN                                    NaN
# 2                             NaN                                    NaN
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
#
#   click.UserAgent.ClientName click.UserAgent.ClientVersion  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#   click.UserAgent.RawString unsubscribe.Timestamp  forward.Timestamp  \
# 0                       NaN                   NaN                NaN
# 1                       NaN                   NaN                NaN
# 2                       NaN                   NaN                NaN
# 3                       NaN                   NaN                NaN
# 4                       NaN                   NaN                NaN
#
#    conversion.cp.Timestamp  conversion.cp.Id  conversion.cp.Name  \
# 0                      NaN               NaN                 NaN
# 1                      NaN               NaN                 NaN
# 2                      NaN               NaN                 NaN
# 3                      NaN               NaN                 NaN
# 4                      NaN               NaN                 NaN
#
#    conversion.cp.OrderId  conversion.cp.ItemCount  conversion.cp.Amount  \
# 0                    NaN                      NaN                   NaN
# 1                    NaN                      NaN                   NaN
# 2                    NaN                      NaN                   NaN
# 3                    NaN                      NaN                   NaN
# 4                    NaN                      NaN                   NaN
#
#    conversion.cp.RequestParameters   group.Id  group.Name  \
# 0                              NaN  900291830  France_all
# 1                              NaN  900291830  France_all
# 2                              NaN  900291830  France_all
# 3                              NaN  900291830  France_all
# 4                              NaN  900291830  France_all
#
#                                   group.Email  group.Category.Id  \
# 0  fr_all@newsletter.swarovski-newsletter.com                241
# 1  fr_all@newsletter.swarovski-newsletter.com                241
# 2  fr_all@newsletter.swarovski-newsletter.com                241
# 3  fr_all@newsletter.swarovski-newsletter.com                241
# 4  fr_all@newsletter.swarovski-newsletter.com                241
#
#   group.Category.Name  message.Id  \
# 0             General  2700098965
# 1             General  2700098092
# 2             General  2700097824
# 3             General  2700097605
# 4             General  2700096897
#
#                                                message.Name  \
# 0      180915_fr_FR_FW18_RemixNecklaces_GwPPwP_All_no_TestN
# 1         180904_fr_FR_FW18_RemixCharms_GwPPwP_All_no_TestN
# 2  180829_fr_FR_FW18_RemixNewCollection_GwPPwP_All_no_TestN
# 3             180825_fr_FR_FW18_IconicUGC_None_All_no_TestN
# 4        180820_fr_FR_Outlet18_Outlet2H_Outlet_All_no_TestN
#
#    message.Category.Id  message.Category.Name  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                                                      message.Subject.Unresolved  \
# 0              Boîte à bijoux Remix offerte │Nouveautés : zoom sur les colliers
# 1       Boîte à bijoux offerte ! Comment personnaliser votre style cette saison
# 2  Boîte à bijoux offerte ! Découvrez les nouveautés Swarovski Remix Collection
# 3                                            Découvrez l'Instagram de Swarovski
# 4                                      OUTLET / Trouvez le look estival parfait
#
#    message.ExternalId message.Type message.variation.Id  selection.Id  \
# 0                 NaN       normal                  NaN           NaN
# 1                 NaN       normal                  NaN           NaN
# 2                 NaN       normal                  NaN           NaN
# 3                 NaN       normal                  NaN           NaN
# 4                 NaN       normal                  NaN           NaN
#
#   selection.Name      record.Timestamp record.Type record.sentToMTA.Timestamp  \
# 0            NaN  2018-09-15T07:33:20Z   SentToMTA       2018-09-15T07:33:20Z
# 1            NaN  2018-09-04T08:46:36Z   SentToMTA       2018-09-04T08:46:36Z
# 2            NaN  2018-08-29T08:46:44Z   SentToMTA       2018-08-29T08:46:44Z
# 3            NaN  2018-08-25T08:46:01Z   SentToMTA       2018-08-25T08:46:01Z
# 4            NaN  2018-08-20T08:31:09Z   SentToMTA       2018-08-20T08:31:09Z
#
#    record.ExternalTransactionId sendout.Type sendout.AddresseeRole  \
# 0                           NaN        MAJOR                NORMAL
# 1                           NaN        MAJOR                NORMAL
# 2                           NaN        MAJOR                NORMAL
# 3                           NaN        MAJOR                NORMAL
# 4                           NaN        MAJOR                NORMAL
#
#   sendout.RecipientType              user.DateOfBirth user.FirstName  \
# 0                    TO  1986-06-05T02:00:00.000+0200            Tan
# 1                    TO  1986-06-05T02:00:00.000+0200            Tan
# 2                    TO  1986-06-05T02:00:00.000+0200            Tan
# 3                    TO  1986-06-05T02:00:00.000+0200            Tan
# 4                    TO  1986-06-05T02:00:00.000+0200            Tan
#
#   user.ISOCountryCode user.ISOLanguageCode  user.Nickname  user.PartnerId  \
# 0                  FR                   fr            NaN             NaN
# 1                  FR                   fr            NaN             NaN
# 2                  FR                   fr            NaN             NaN
# 3                  FR                   fr            NaN             NaN
# 4                  FR                   fr            NaN             NaN
#
#   user.Source  user.TimeZone  user.Title user.ZipCode  \
# 0           i            NaN         2.0          NaN
# 1           i            NaN         2.0          NaN
# 2           i            NaN         2.0          NaN
# 3           i            NaN         2.0          NaN
# 4           i            NaN         2.0          NaN
#
#    user.CustomAttribute['BeSCity']  user.CustomAttribute['BeSHome']  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    user.CustomAttribute['BeSHome2']  user.CustomAttribute['BeSHome3']  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    user.CustomAttribute['BeSStreet']  user.CustomAttribute['BesZip']  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    user.CustomAttribute['BIC'] user.CustomAttribute['City']  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   user.CustomAttribute['Coupon']  user.CustomAttribute['Coupon02']  \
# 0               BD18Q2_FR_JY8YP4                               NaN
# 1               BD18Q2_FR_JY8YP4                               NaN
# 2               BD18Q2_FR_JY8YP4                               NaN
# 3               BD18Q2_FR_JY8YP4                               NaN
# 4               BD18Q2_FR_JY8YP4                               NaN
#
#    user.CustomAttribute['IBAN']  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   user.CustomAttribute['Last_Open_Any_Newsletter_Date']  \
# 0                                  2017-12-22T06:18:59Z
# 1                                  2017-12-22T06:18:59Z
# 2                                  2017-12-22T06:18:59Z
# 3                                  2017-12-22T06:18:59Z
# 4                                  2017-12-22T06:18:59Z
#
#   user.CustomAttribute['PartnerID']  user.CustomAttribute['ProductID']  \
# 0                        C032808108                                NaN
# 1                        C032808108                                NaN
# 2                        C032808108                                NaN
# 3                        C032808108                                NaN
# 4                        C032808108                                NaN
#
#    user.CustomAttribute['SalesOrganization']  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    user.CustomAttribute['SCSMembernumber']  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    user.CustomAttribute['SCS_Boutique']  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    user.CustomAttribute['SCS_Boutique_City']  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    user.CustomAttribute['SCS_Boutique_Name1']  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    user.CustomAttribute['SCS_Boutique_Name2']  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    user.CustomAttribute['SCS_Boutique_Street']  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    user.CustomAttribute['SCS_Due_Date']  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    user.CustomAttribute['SCS_Entry_Date']  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   user.CustomAttribute['SCS_Expiry_Dat']  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    user.CustomAttribute['SCS_Magazine_Language_ISO']  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    user.CustomAttribute['SSFCardNumber'] user.CustomAttribute['Street']  \
# 0                                    NaN                            NaN
# 1                                    NaN                            NaN
# 2                                    NaN                            NaN
# 3                                    NaN                            NaN
# 4                                    NaN                            NaN
#
#    user.CustomAttribute['Street2']  user.CustomAttribute['Street3']  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    user.CustomAttribute['Telephone']  user.CustomAttribute['TitleKey']
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN

# %% [markdown]
# ## Timestamps
#
# Timestamps mark the events
# - sentToMTA
# - skipped
# - bounced
# - feedback
# - render
# - clicked
# - forwarded
# - unsubscribed
# - conversion
#
# We want to check if these events are disjoint

# %%
sum = 0
timestamps = []
for col_name in chunk.columns:
    if 'Timestamp' in col_name:
        timestamps.append([col_name, chunk[chunk[col_name].notna()].shape[0]])

pd_timestamps = pd.DataFrame(timestamps, columns=['event', 'count'])
display(pd_timestamps)
print('\nsum = ' + str(pd_timestamps['count'].sum()), )
# Out:
#                          event  count
# 0          sentToMTA.Timestamp   8042
# 1               skip.Timestamp    214
# 2             bounce.Timestamp      2
# 3           feedback.Timestamp      0
# 4             render.Timestamp   1385
# 5              click.Timestamp    349
# 6        unsubscribe.Timestamp      8
# 7            forward.Timestamp      0
# 8      conversion.cp.Timestamp      0
# 9             record.Timestamp  10000
# 10  record.sentToMTA.Timestamp  10000
# sum = 30000

# %% [markdown]
# ## Findings
# - every record has `record.Timestamp` and `record.sentToMTATimestamp` set
# - exactly one of the remaining Timestamps is set in each record
