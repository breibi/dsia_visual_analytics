# %% [markdown]
# # Part 1: Analyze File Structure

# %%
import pandas as pd
import os
import gzip
import shutil
import warnings

warnings.filterwarnings('ignore')
pd.options.display.max_columns = None
pd.options.display.max_rows = 150

# %% [markdown]
# ## Number and Size of Files
#
# First, we read the data directory from a config file:

# %%
with open('config') as f:
    path = f.readline()

# %% [markdown]
# display files and sizes:

# %%
files = pd.DataFrame()
for i, filename in enumerate(os.listdir(path)):
    full_path = os.path.join(path, filename)
    files =pd.concat([files, pd.DataFrame([['file' + str(i)+'.csv', round(os.path.getsize(full_path)/1024)]])], ignore_index=True)

files.columns = ['filename', 'size [KB]']
files.head()
# Out:
#     filename  size [KB]
# 0  file0.csv      97671
# 1  file1.csv      97677
# 2  file2.csv      97681
# 3  file3.csv      97670
# 4  file4.csv      97678

# %%
print("Number of Files: {}".format(len(files)))
print("Total Size: {} MB".format(int(files['size [KB]'].sum()/1024)))
# Out:
# Number of Files: 237
# Total Size: 22416 MB

# %% [markdown]
# ## Analyze the structure
# - we choose a sample file (nr 230 in the list)
# - unzip it to a temporary file
# - read the first chunk of 10000 entries

# %%
tmp_file = '.\\data\\tmp.csv'
sample_filename = os.listdir(path)[230]

# unzip to tmp_file
with gzip.open(os.path.join(path,sample_filename)) as f_in:
    with open(tmp_file, 'wb') as f_out:
                shutil.copyfileobj(f_in, f_out)

reader = pd.read_csv(tmp_file, sep=';', chunksize=10000)
chunk = next(reader)

# %% [markdown]
# drop columns with all NA values

# %%
chunk.dropna(axis=1, how='all', inplace=True)

# %% [markdown]
# ## some entries...
# but first drop personal data

# %%
chunk = chunk.loc[:, ~chunk.columns.str.contains('user')]
chunk = chunk.drop(columns=['group.Email', 'message.Subject.Unresolved', 'message.Name'])
chunk.head()
# Out:
#     sentToMTA.Timestamp sentToMTA.SendoutChannel skip.Timestamp skip.Category  \
# 0  2018-09-15T07:33:20Z                    EMAIL            NaN           NaN
# 1  2018-09-04T08:46:36Z                    EMAIL            NaN           NaN
# 2  2018-08-29T08:46:44Z                    EMAIL            NaN           NaN
# 3  2018-08-25T08:46:01Z                    EMAIL            NaN           NaN
# 4  2018-08-20T08:31:09Z                    EMAIL            NaN           NaN
#
#   bounce.Timestamp bounce.Category render.Timestamp  \
# 0              NaN             NaN              NaN
# 1              NaN             NaN              NaN
# 2              NaN             NaN              NaN
# 3              NaN             NaN              NaN
# 4              NaN             NaN              NaN
#
#   render.GeoLocation.ISOCountryCode render.GeoLocation.RegionCode  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
#
#   render.GeoLocation.City  render.GeoLocation.Latitude  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    render.GeoLocation.Longitude render.UserAgent.Platform  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   render.UserAgent.OperatingSystemName  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   render.UserAgent.OperatingSystemVersion render.UserAgent.ClientName  \
# 0                                     NaN                         NaN
# 1                                     NaN                         NaN
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                     NaN                         NaN
#
#   render.UserAgent.ClientVersion render.UserAgent.RawString click.Timestamp  \
# 0                            NaN                        NaN             NaN
# 1                            NaN                        NaN             NaN
# 2                            NaN                        NaN             NaN
# 3                            NaN                        NaN             NaN
# 4                            NaN                        NaN             NaN
#
#    click.Link.Id  click.Link.Category.Id click.Link.Category.Name  \
# 0            NaN                     NaN                      NaN
# 1            NaN                     NaN                      NaN
# 2            NaN                     NaN                      NaN
# 3            NaN                     NaN                      NaN
# 4            NaN                     NaN                      NaN
#
#   click.Link.Url click.Link.Type click.GeoLocation.ISOCountryCode  \
# 0            NaN             NaN                              NaN
# 1            NaN             NaN                              NaN
# 2            NaN             NaN                              NaN
# 3            NaN             NaN                              NaN
# 4            NaN             NaN                              NaN
#
#   click.GeoLocation.RegionCode click.GeoLocation.City  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
#
#    click.GeoLocation.Latitude  click.GeoLocation.Longitude  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#   click.UserAgent.Platform click.UserAgent.OperatingSystem  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
#   click.UserAgent.OperatingSystemVersion click.UserAgent.ClientName  \
# 0                                    NaN                        NaN
# 1                                    NaN                        NaN
# 2                                    NaN                        NaN
# 3                                    NaN                        NaN
# 4                                    NaN                        NaN
#
#   click.UserAgent.ClientVersion click.UserAgent.RawString  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   unsubscribe.Timestamp   group.Id  group.Name  group.Category.Id  \
# 0                   NaN  900291830  France_all                241
# 1                   NaN  900291830  France_all                241
# 2                   NaN  900291830  France_all                241
# 3                   NaN  900291830  France_all                241
# 4                   NaN  900291830  France_all                241
#
#   group.Category.Name  message.Id message.Type message.variation.Id  \
# 0             General  2700098965       normal                  NaN
# 1             General  2700098092       normal                  NaN
# 2             General  2700097824       normal                  NaN
# 3             General  2700097605       normal                  NaN
# 4             General  2700096897       normal                  NaN
#
#    selection.Id selection.Name      record.Timestamp record.Type  \
# 0           NaN            NaN  2018-09-15T07:33:20Z   SentToMTA
# 1           NaN            NaN  2018-09-04T08:46:36Z   SentToMTA
# 2           NaN            NaN  2018-08-29T08:46:44Z   SentToMTA
# 3           NaN            NaN  2018-08-25T08:46:01Z   SentToMTA
# 4           NaN            NaN  2018-08-20T08:31:09Z   SentToMTA
#
#   record.sentToMTA.Timestamp sendout.Type sendout.AddresseeRole  \
# 0       2018-09-15T07:33:20Z        MAJOR                NORMAL
# 1       2018-09-04T08:46:36Z        MAJOR                NORMAL
# 2       2018-08-29T08:46:44Z        MAJOR                NORMAL
# 3       2018-08-25T08:46:01Z        MAJOR                NORMAL
# 4       2018-08-20T08:31:09Z        MAJOR                NORMAL
#
#   sendout.RecipientType
# 0                    TO
# 1                    TO
# 2                    TO
# 3                    TO
# 4                    TO

# %% [markdown]
# ## column names

# %%
chunk.dtypes
# Out:
# sentToMTA.Timestamp                         object
# sentToMTA.SendoutChannel                    object
# skip.Timestamp                              object
# skip.Category                               object
# bounce.Timestamp                            object
# bounce.Category                             object
# render.Timestamp                            object
# render.GeoLocation.ISOCountryCode           object
# render.GeoLocation.RegionCode               object
# render.GeoLocation.City                     object
# render.GeoLocation.Latitude                float64
# render.GeoLocation.Longitude               float64
# render.UserAgent.Platform                   object
# render.UserAgent.OperatingSystemName        object
# render.UserAgent.OperatingSystemVersion     object
# render.UserAgent.ClientName                 object
# render.UserAgent.ClientVersion              object
# render.UserAgent.RawString                  object
# click.Timestamp                             object
# click.Link.Id                              float64
# click.Link.Category.Id                     float64
# click.Link.Category.Name                    object
# click.Link.Url                              object
# click.Link.Type                             object
# click.GeoLocation.ISOCountryCode            object
# click.GeoLocation.RegionCode                object
# click.GeoLocation.City                      object
# click.GeoLocation.Latitude                 float64
# click.GeoLocation.Longitude                float64
# click.UserAgent.Platform                    object
# click.UserAgent.OperatingSystem             object
# click.UserAgent.OperatingSystemVersion      object
# click.UserAgent.ClientName                  object
# click.UserAgent.ClientVersion               object
# click.UserAgent.RawString                   object
# unsubscribe.Timestamp                       object
# group.Id                                     int64
# group.Name                                  object
# group.Category.Id                            int64
# group.Category.Name                         object
# message.Id                                   int64
# message.Type                                object
# message.variation.Id                        object
# selection.Id                               float64
# selection.Name                              object
# record.Timestamp                            object
# record.Type                                 object
# record.sentToMTA.Timestamp                  object
# sendout.Type                                object
# sendout.AddresseeRole                       object
# sendout.RecipientType                       object
# dtype: object

# %% [markdown]
# ## Timestamps
#
# Timestamps mark the events
# - sentToMTA
# - skipped
# - bounced
# - feedback
# - render
# - clicked
# - forwarded
# - unsubscribed
# - conversion
#
# We want to check if these events are disjoint

# %%
sum = 0
timestamps = []
for col_name in chunk.columns:
    if 'Timestamp' in col_name:
        timestamps.append([col_name, chunk[chunk[col_name].notna()].shape[0]])

pd_timestamps = pd.DataFrame(timestamps, columns=['event', 'count'])
display(pd_timestamps)
print('\nsum = ' + str(pd_timestamps['count'].sum()), )
# Out:
#                         event  count
# 0         sentToMTA.Timestamp   8042
# 1              skip.Timestamp    214
# 2            bounce.Timestamp      2
# 3            render.Timestamp   1385
# 4             click.Timestamp    349
# 5       unsubscribe.Timestamp      8
# 6            record.Timestamp  10000
# 7  record.sentToMTA.Timestamp  10000
# sum = 30000

# %% [markdown]
# ## Findings
# - every record has `record.Timestamp` and `record.sentToMTATimestamp` set
# - exactly one of the remaining Timestamps is set in each record
